# %%
import pickle
import os

def rePickle(name):
    pickle3 = pickle.load( open( "weaksymMonodentatesProj/" + str(name), "rb" ) )
    pickle.dump(pickle3, file=open("weaksymMonodentatesProj/" + str(name) + '2', "wb"), protocol=2)
    
for file in os.listdir("weaksymMonodentatesProj/"):
    print(file)
    rePickle(file)
# Out:
# weaksymMonodentatesProj_020.p
# weaksymMonodentatesProj_190.p
# weaksymMonodentatesProj_165.p
# weaksymMonodentatesProj_257.p
# weaksymMonodentatesProj_051.p
# weaksymMonodentatesProj_145.p
# weaksymMonodentatesProj_182.p
# weaksymMonodentatesProj_200.p
# weaksymMonodentatesProj_352.p
# weaksymMonodentatesProj_280.p
# weaksymMonodentatesProj_141.p
# weaksymMonodentatesProj_193.p
# weaksymMonodentatesProj_266.p
# weaksymMonodentatesProj_099.p
# weaksymMonodentatesProj_330.p
# weaksymMonodentatesProj_024.p
# weaksymMonodentatesProj_377.p
# weaksymMonodentatesProj_036.p
# weaksymMonodentatesProj_019.p
# weaksymMonodentatesProj_183.p
# weaksymMonodentatesProj_199.p
# weaksymMonodentatesProj_185.p
# weaksymMonodentatesProj_389.p
# weaksymMonodentatesProj_259.p
# weaksymMonodentatesProj_130.p
# weaksymMonodentatesProj_027.p
# weaksymMonodentatesProj_195.p
# weaksymMonodentatesProj_285.p
# weaksymMonodentatesProj_134.p
# weaksymMonodentatesProj_291.p
# weaksymMonodentatesProj_010.p
# ...
